# %% [markdown]
# Hello Guys
# Welcome to Tushar's Hub
# The below is the step wise data analysis of a sample sales data which i have attached above this files in same folder.
# So let's start now

# %%
#first we need to install the necessary libraries such as Numpy, pandas, matplotlib and Seaborne. Do install them one at a time
# !pip install numpy

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("D:\\1st project EDA\\Diwali Sales Data.csv", encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.head(100)
# Out:
#     User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903   Sanskriti  P00125942      F     26-35   28               0
# 1   1000732      Kartik  P00110942      F     26-35   35               1
# 2   1001990       Bindu  P00118542      F     26-35   35               1
# 3   1001425      Sudevi  P00237842      M      0-17   16               0
# 4   1000588        Joni  P00057942      M     26-35   28               1
# ..      ...         ...        ...    ...       ...  ...             ...
# 95  1004416       Airdo  P00213742      F     18-25   23               0
# 96  1000850      Bhawna  P00319942      F     36-45   44               0
# 97  1002888  Corey-Lock  P00255842      F     26-35   34               0
# 98  1001891        Akin  P00192542      F     46-50   46               0
# 99  1001019        Neil  P00259142      F     36-45   43               1
#
#              State      Zone       Occupation  Product_Category  Orders  \
# ...

# %%
df.info() # to get info of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'], axis =1 , inplace=True) # to drop/ remove the null value columns

# %%
pd.isnull(df).sum() # to cross- check the removed columns
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True) # we use inplace to save the droped column

# %%
df['Amount'] = df['Amount'].astype('int')

# %%
df.dtypes # it shows the data types
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int32
# dtype: object

# %%
df.columns # it shows the data columns present in the file
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Occupation' : 'Profession'}) #used for rename a column
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.describe #describes the data
# Out:
# <bound method NDFrame.describe of        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# Exploratory Data Analysis

# %%
Gender #let us first consider this feature and explore our data

# %%
#step 1 
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#Step 2 
ax= sns.countplot(x='Gender',data=df) 
#sns is seaborne and data is our data frame  
#we addd the below to get values to our bars in graphs/charts 
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Step 3 
sales_gen= df.groupby(['Gender'],as_index= False)['Amount'].sum().sort_values(by='Amount', ascending = False )  

#GroupBy in Python and SQL is used to separate identical data into groups to allow for further aggregation and analysis. 
#A GroupBy in Python is performed using the pandas library groupby() function .

sns.barplot(x= 'Gender', y='Amount', data = sales_gen )
# we plot a graph taking Gender and Amount in X And Y axis resplectively
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
Age 
# the second criteria

# %%
df.columns # we use the step 1
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# same as Step 2 
ax=sns.countplot (x='Age Group', data=df, hue= 'Gender')  # we execute the Step 2 
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Step 3 
sales_age= df.groupby(['Age Group'],as_index= False)['Amount'].sum().sort_values(by='Amount', ascending = False )  

sns.barplot(x='Age Group', y='Amount', data = sales_age )
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
State 
# Criteria no 3 to check which state makes the most orders

# %%
df.columns #s1
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# s2 we are finding taotal order in staes 

sales_State= df.groupby(['State'],as_index= False)['Orders'].sum().sort_values(by='Orders', ascending = False ).head(7)
#you can change head values in order to get desired number of entries 
# now we set the size of our bar in the plot/graph
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x='State', y='Orders', data = sales_age )
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# s3 we now find total amount of sales in states
sales_State= df.groupby(['State'],as_index= False)['Amount'].sum().sort_values(by='Amount', ascending = False ).head(7)

sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x='State', y='Amount', data=sales_State)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# Marital Status
# #criteria no 4

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x='Marital_Status', data=df)
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_State= df.groupby(['Marital_Status','Gender'],as_index= False)['Amount'].sum().sort_values(by='Amount', ascending = False )

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marital_Status', y='Amount', data=sales_State, hue = 'Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
Occupation 
#criteria 4

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sales_State= df.groupby(['Occupation'],as_index= False)['Amount'].sum().sort_values(by='Amount', ascending = False )

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Occupation', y='Amount', data=sales_State)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
ax = sns.countplot(x='Occupation', data=df)
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
Product_Category
#Criteria 5

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sales_pc= df.groupby(['Product_Category'],as_index= False)['Orders'].sum().sort_values(by='Orders', ascending = False )

sns.set(rc={'figure.figsize':(35,5)})
sns.barplot(x='Product_Category', y='Orders', data=sales_State)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Orders'>

# %%
sns.set(rc={'figure.figsize':(25,5)})
ax = sns.countplot(x='Product_Category', data= df)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [raw]
# Finally, Let us take the TOP Selling Products and see which product is sold the most.

# %%
fig1, ax1 = plt.subplots(figsize = (12,5))
df.groupby('Product_ID') ['Orders'].sum().nlargest(10).sort_values(ascending= False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
The product p00265242 is the best selling product. This was my prroject on EDA. 
Follow for more projects and insights about Data Anlytics. 
You can reach me out on linked In ( www.linkedin.com/in/tushar-r-data-analyst111 )

thank you,
Tushar R
